# %% [markdown]
#  """
#  ## Simplify Estonian Sentences with Saved Model
#
# Author: Eduard Barbu
#
# Contact: eduard.barbu@ut.ee
#
# This script handles two scenarios for simplifying Estonian sentences:
# 1. Simplifying a dataset with columns ["source", "original", "simplified", "corrected"].
#
# 2. Simplifying sentences from a file where each line contains a number and a sentence to simplify.
#
# Ensure the appropriate input format for the chosen scenario and specify the file paths accordingly.
#
# ## Dependencies:
# - `unsloth`
# - `datasets`
# - `pandas`
# """

# %%
# %%capture
# Install required packages in Google Colab
# !pip install torch==2.0.0+cu118 torchvision==0.15.0+cu118 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps trl peft accelerate bitsandbytes
# !pip install "xformers<=0.0.27" --no-cache-dir
# !pip install numpy==1.23.5
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==2.0.0+cu118
#   Using cached https://download.pytorch.org/whl/cu118/torch-2.0.0%2Bcu118-cp311-cp311-linux_x86_64.whl (2267.3 MB)
# Requirement already satisfied: torchvision==0.15.0+cu118 in /usr/local/lib/python3.11/dist-packages (0.15.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.0+cu118) (3.17.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.0+cu118) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.0+cu118) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.0+cu118) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.0+cu118) (3.1.5)
# Collecting triton==2.0.0 (from torch==2.0.0+cu118)
#   Using cached triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.0+cu118) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.0+cu118) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.0+cu118) (11.1.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.0+cu118) (3.31.4)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.0+cu118) (18.1.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.0+cu118) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.0+cu118) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.0+cu118) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.0+cu118) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.0+cu118) (2024.12.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.0+cu118) (1.3.0)
# Using cached triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# Installing collected packages: triton, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.1
#     Uninstalling triton-2.3.1:
#       Successfully uninstalled triton-2.3.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.1
#     Uninstalling torch-2.3.1:
#       Successfully uninstalled torch-2.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xformers 0.0.27 requires torch==2.3.1, but you have torch 2.0.0+cu118 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.0.0+cu118 which is incompatible.
# Successfully installed torch-2.0.0+cu118 triton-2.0.0
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-fpzoyd8g/unsloth_39d2e5019eac48bfb5c6d1094a75999d
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-fpzoyd8g/unsloth_39d2e5019eac48bfb5c6d1094a75999d
#   Resolved https://github.com/unslothai/unsloth.git to commit bdf0cd6033595be4e7ed23d0d002bb176d343152
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: unsloth_zoo>=2025.1.4 in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2025.1.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.2)
# Requirement already satisfied: tyro in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.9.13)
# Requirement already satisfied: transformers!=4.47.0,>=4.46.1 in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.47.1)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.2.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.23.5)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.27.1)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.9)
# Requirement already satisfied: bitsandbytes>=0.43.3 in /usr/local/lib/python3.11/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.45.1)
# Requirement already satisfied: torch~=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.11.11)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.47.0,>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.47.0,>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.47.0,>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.5.2)
# Requirement already satisfied: triton<3.2.0 in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.0.0)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.2.1)
# Requirement already satisfied: trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.13.0)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.14.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (25.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.1.0)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.7.1)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.18.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.5)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton<3.2.0->unsloth_zoo>=2025.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.31.4)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton<3.2.0->unsloth_zoo>=2025.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (18.1.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2025.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch~=2.0->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch~=2.0->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: trl in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.2.1)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.45.1)
# Requirement already satisfied: xformers<=0.0.27 in /usr/local/lib/python3.11/dist-packages (0.0.27)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xformers<=0.0.27) (1.23.5)
# Collecting torch==2.3.1 (from xformers<=0.0.27)
#   Downloading torch-2.3.1-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->xformers<=0.0.27) (12.1.105)
# Collecting triton==2.3.1 (from torch==2.3.1->xformers<=0.0.27)
#   Downloading triton-2.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->xformers<=0.0.27) (12.8.61)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.3.1->xformers<=0.0.27) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.3.1->xformers<=0.0.27) (1.3.0)
# Downloading torch-2.3.1-cp311-cp311-manylinux1_x86_64.whl (779.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.2/779.2 MB 299.4 MB/s eta 0:00:00
# Downloading triton-2.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 289.7 MB/s eta 0:00:00
# Installing collected packages: triton, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.15.0+cu118 requires torch==2.0.0+cu118, but you have torch 2.3.1 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.3.1 which is incompatible.
# Successfully installed torch-2.3.1 triton-2.3.1
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.11/dist-packages (1.23.5)

# %%
import xformers
print(xformers.__version__)
# Out:
# 0.0.27

# %%
from google.colab import drive
import os
drive.mount('/content/drive')

# Define the path to the Google Drive directory containing the data and model
directory_path = '/content/drive/MyDrive/DataToShare/Estonian-Text-Simplification/Data/Estonian-Training-And-Test-Sets'
model_save_path = os.path.join(directory_path, "models", "fine_tuned_model")
template_file_path = os.path.join(directory_path, 'template-simplification-llama.txt')

# Print the path where the model is stored
print(f"Model is stored at: {model_save_path}")

# Define the scenario: "dataset" or "numbered_sentences"
scenario = "dataset"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model is stored at: /content/drive/MyDrive/DataToShare/Estonian-Text-Simplification/Data/Estonian-Training-And-Test-Sets/models/fine_tuned_model

# %%
def read_tsv_file(file_path, columns):
    data = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split('\t')
            if len(parts) == len(columns):
                data.append(parts)
            else:
                print(f"Skipping line: {line}")
    return pd.DataFrame(data, columns=columns)


def read_template(file_path):
    """
    Reads a template file and returns its content as a string.

    Args:
        file_path (str): Path to the template file.

    Returns:
        str: Content of the template file.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

# %%
import os
import pandas as pd
from datasets import Dataset
from unsloth import FastLanguageModel
import torch
import time

# Load data based on the selected scenario
if scenario == "dataset":
    # Scenario 1: Simplify a dataset with columns ["source", "original", "simplified", "corrected"]
    test_file_path = os.path.join(directory_path, 'Test-Sets', 'Estonian-TestSet.tsv')
    test_columns = ["source", "original", "simplified", "corrected"]
    test_df = read_tsv_file(test_file_path, test_columns)
    test_df.reset_index(drop=True, inplace=True)
elif scenario == "numbered_sentences":
    # Scenario 2: Simplify sentences from a file with number and sentence
    input_file_path = os.path.join(directory_path, 'article-fictitious.txt')
    numbered_sentences = []
    with open(input_file_path, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split('\t')
            if len(parts) == 2:
                numbered_sentences.append((parts[0].strip(), parts[1].strip()))
            else:
                print(f"Skipping line: {line}")
else:
    raise ValueError("Invalid scenario. Choose 'dataset' or 'numbered_sentences'.")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
# Load the model and tokenizer
print("Loading model and tokenizer...")
try:
    max_seq_length = 2048  # Set maximum sequence length
    dtype = None  # Auto-detect data type. Use Float16 for T4/V100 or BFloat16 for Ampere.
    load_in_4bit = True  # Use 4-bit quantization to save memory

    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=model_save_path,
        max_seq_length=max_seq_length,
        dtype=dtype,
        load_in_4bit=load_in_4bit,
    )
    print("Model and tokenizer loaded successfully.")
except Exception as e:
    print(f"Failed to load model and tokenizer: {e}")
    model, tokenizer = None, None
    raise e

# Enable fast inference
try:
    print("Enabling fast inference...")
    FastLanguageModel.for_inference(model)
    print("Fast inference enabled.")
except Exception as e:
    print(f"Failed to enable fast inference: {e}")
    raise e
# Out:
# Loading model and tokenizer...
# ==((====))==  Unsloth 2025.1.7: Fast Llama patching. Transformers: 4.47.1.
#    \\   /|    GPU: NVIDIA L4. Max memory: 22.168 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.3.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 2.3.1
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.27. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# unsloth/Meta-Llama-3.1-8B-bnb-4bit does not have a padding token! Will use pad_token = <|finetune_right_pad_id|>.
# Unsloth 2025.1.7 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.
# Model and tokenizer loaded successfully.
# Enabling fast inference...
# Fast inference enabled.

# %%
def simplify_sentence(sentence, simplification_template, tokenizer, model):
    """
    Simplifies a given sentence using the trained model with fast inference enabled.
    The prompt for the model is constructed based on a provided template.

    Args:
        sentence (str): The sentence to simplify.
        simplification_template (str): The template used to construct the prompt.
        tokenizer: The tokenizer for the model.
        model: The trained model.

    Returns:
        str: The simplified sentence.
    """
    # Replace the placeholder in the template with the actual sentence
    prompt = simplification_template.replace("{input_sentence}", sentence)

    # Tokenize and generate the simplified sentence
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    outputs = model.generate(
        **inputs,
        max_new_tokens=100,
        use_cache=True,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id
    )
    simplified_sentence = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0].strip()

    # Extract the part after "### Simplified version:"
    if "### Simplified version:" in simplified_sentence:
        simplified_sentence = simplified_sentence.split("### Simplified version:")[1].strip()

    return simplified_sentence

# %%
if scenario == "dataset":
    # Simplify the dataset
    print("Simplifying dataset...")
    simplified_sentences = []
    simplification_template=read_template(template_file_path)
    for original_sentence in test_df['original']:
        start_time = time.time()  # Start timing
        simplified = simplify_sentence(original_sentence, simplification_template, tokenizer, model)
        end_time = time.time()  # End timing
        time_taken = end_time - start_time

        # Print original, simplified sentence, and time taken
        print(f"Original sentence:\n{original_sentence}")
        print(f"Simplified sentence:\n{simplified}")
        print(f"Time taken: {time_taken:.2f} seconds")
        print("--------------------------------------------------------")

        simplified_sentences.append(simplified)
    test_df['simplified'] = simplified_sentences

    # Save results to a TSV file
    output_file_path = os.path.join(directory_path, 'Estonian-Predictions-Dataset.tsv')
    test_df.to_csv(output_file_path, sep='\t', index=False, encoding='utf-8')
    print(f"Simplified dataset saved to {output_file_path}")

elif scenario == "numbered_sentences":
    # Simplify sentences from the numbered file
    print("Simplifying numbered sentences...")
    simplified_sentences = []
    for number, original_sentence in numbered_sentences:
        start_time = time.time()  # Start timing
        simplified = simplify_sentence(original_sentence, simplification_template, tokenizer, model)
        end_time = time.time()  # End timing
        time_taken = end_time - start_time

        # Print number, original, simplified sentence, and time taken
        print(f"Number: {number}")
        print(f"Original sentence:\n{original_sentence}")
        print(f"Simplified sentence:\n{simplified}")
        print(f"Time taken: {time_taken:.2f} seconds")
        print
# Out:
# Simplifying dataset...
# Original sentence:
# Esimest tüüpi Wolframi sündroom on põhjustatud mutatsioonidest WFS1 geenis, kuid teist tüüpi sündroom on põhjustatud mutatsioonidest CSID2 geenis.
# Simplified sentence:
# Esimest tüüpi Wolframi sündroom on põhjustatud WFS1 geeni mutatsioonidest. Teist tüüpi sündroom on põhjustatud CSID2 geeni mutatsioonidest.
# Time taken: 6.77 seconds
# --------------------------------------------------------
# Original sentence:
# Gormi poeg Harald Sinihammas rajas Jellingisse oma vanematele vägeva hauamonumendi, mis koosneb kahest hiiglaslikust kääpast, kahest ruunikivist, suurest kivilaevast ja kirikust.
# Simplified sentence:
# Gormi poeg Harald Sinihammas ehitas Jellingisse oma vanematele vägeva hauamonumendi. See monumendi koosneb kahest suurest kääpast, kahest ruunikivist, suurest kivilaevast ja kirikust.
# Time taken: 4.31 seconds
# --------------------------------------------------------
# Original sentence:
# Sellegipoolest oli segmentide kirjeldajate laadimine kulukas operatsioon, mistõttu jäid operatsioonisüsteemide loojad tihti saalimise juurde, selmet saalimist ja segmentatsiooni kombineeritult kasutada.
# Simplified sentence:
# Operatsiooni, kus segmentide kirjeldajate laadimine, oli kallis. Seetõttu jäid operatsioonisüsteemide loojad tihti kasutama saalimise ja segmentatsiooni kombineeritult.
# Time taken: 3.84 seconds
# --------------------------------------------------------
# Original sentence:
# Üksiku inimese aju genereerib midagi ideaalset üksnes siis, kui ta hakkab teenindama inimkonna "mitteorgaanilise keha" (kultuuri) vajadusi.
# Simplified sentence:
# Aju genereerib midagi ideaalset ainult siis, kui see teenindab inimkonna "mitteorgaanilise keha" vajadusi. See "mitteorgaaniline keha" tähendab kultuuri.
# Time taken: 3.94 seconds
# --------------------------------------------------------
# Original sentence:
# 20. sajandi algul kasvas ruunide maagiline rakendamine seoses Saksamaal levinud müstitsismiga, Hitler aitas kaasa selle ikonograafia levikule seoses völkisch liikumisega, pärast Natsi-Saksamaa langust selle populaarsus vähenes.
# Simplified sentence:
# 20. sajandi alguses kasvasid ruunide kasutus seoses Saksamaal levinud müstitsismiga. Hitler aitas kaasa ruunide kasutuse levikule, sest ta oli völkisch liikumise liige. Pärast Natsi-Saksamaa langust muutusid ruunid vähem populaarsed.
# Time taken: 5.69 seconds
# --------------------------------------------------------
# Original sentence:
# Oklahoma osariigi esimene lipp võeti kasutusele 1911. aastal, sellest ajast on selle kujundust mitmel korral muudetud, kuigi praeguse lipu põhielemendid on suures osas samad alates 1925. aastast.
# Simplified sentence:
# Oklahoma osariigi esimene lipp võeti kasutusele 1911. aastal. Sellest ajast on selle kujundust mitu korda muudetud. Kuid alates 1925. aastast on praeguse lipu põhielemendid suuresti samad.
# Time taken: 4.89 seconds
# --------------------------------------------------------
# Original sentence:
# Hispaania lennuvägi tellis 1938. aasta alguses 12 He 112B lennukit ning suurendas hiljem seda tellimust veel kuue lennuki võrra.
# Simplified sentence:
# Hispaania lennuvägi tellis 1938. aasta alguses 12 He 112B lennukit. Hiljem suurendas nad seda tellimust veel kuue lennuki võrra.
# Time taken: 3.41 seconds
# --------------------------------------------------------
# Original sentence:
# Lisaks on 10 maapealset jaama ja neli kõrgemal asuvat.
# Simplified sentence:
# On 10 maapealset jaama ja neli kõrgemal asuvat.
# Time taken: 1.47 seconds
# --------------------------------------------------------
# Original sentence:
# Aastal 1861 ühendati osad Caldwelli maakonnast, Burke'i maakonnast, McDowelli maakonnast, Watauga maakonnast ja Yancey maakonnast, et moodustada Mitchelli maakond.
# Simplified sentence:
# Aastal 1861 loodi Mitchelli maakond. See loodi, kui osad Caldwelli maakonnast, Burke'i maakonnast, McDowelli maakonnast, Watauga maakonnast ja Yancey maakonnast ühendati.
# Time taken: 4.12 seconds
# --------------------------------------------------------
# Original sentence:
# Väravavaht kasutab seda kinnast visete tõrjumiseks.
# Simplified sentence:
# Väravavaht kasutab kinnast visete tõrjumiseks.
# Time taken: 1.49 seconds
# --------------------------------------------------------
# Original sentence:
# Ent taastades kontrolli merel, suutis Hispaania oluliselt suurendada kulla ja hõbeda tarnimist Ameerikast, mis võimaldas suurendada sõjalist survet Inglismaale ja Prantsusmaale.
# Simplified sentence:
# Hispaania suutis taastada kontrolli merel. See võimaldas neil suurendada kulla ja hõbeda tarnimist Ameerikast. See võimaldas suurendada sõjalist survet Inglismaale ja Prantsusmaale.
# Time taken: 4.23 seconds
# --------------------------------------------------------
# Original sentence:
# Seksuaalselt väärkoheldud lastele on tagatud kohene ohvriabi: psühholoogiline nõustamine, abi juriidilistes küsimustes, vajadusel ka turvaline majutus, toitlustus ja tervishoiuteenused.
# Simplified sentence:
# Seksuaalselt väärkoheldud lastele on tagatud pidev abi. Nendele on pakkuda psühholoogilist nõustamist, abi juriidilistes küsimustes, vajadusel ka turvaline majutus, toitlustus ja tervishoiuteenused.
# Time taken: 5.14 seconds
# --------------------------------------------------------
# Original sentence:
# Rooma prominentne ooperipublik oli olnud alati uue teose suhtes kahtlev ja mõneti tõrjuv ega kiirustanud piletit ostma.
# Simplified sentence:
# Rooma ooperipublik on olnud alati uue teose suhtes kahtlev ja tõrjuv. Nad ei kiirustanud piletit ostma.
# Time taken: 2.70 seconds
# --------------------------------------------------------
# Original sentence:
# Järgmise nelja aasta jooksul andis ta välja veel kaks albumit, millest viimane, 1993. aastal välja antud "Black Reign" sai kuldplaadi staatuse.
# Simplified sentence:
# Ta andis välja veel kaks albumit järgmise nelja aasta jooksul. Viimane album, "Black Reign", mis ilmus 1993. aastal, sai kuldplaadi staatuse.
# Time taken: 3.24 seconds
# --------------------------------------------------------
# Original sentence:
# Seejärel, 21. detsembril 1994, paiskas vulkaan gaasi ja tuhka, mida valdavad tuuled kandsid kuni 25 km (16 miili) kaugusele.
# Simplified sentence:
# Vulkaan paiskas 21. detsembril 1994 gaasi ja tuhka. Tuuled veetsid seda tuhka kuni 25 km kaugusele.
# Time taken: 2.86 seconds
# --------------------------------------------------------
# Original sentence:
# Skisofreeniale spetsiifilisi sümptomeid ei ole (st samad sümptomid võivad esineda ka muude psüühikahäirete korral), samuti ei esine otseseid spetsiifilisi somaatilisi või füsioloogilisi tunnuseid.
# Simplified sentence:
# Skisofreenia puhul ei esine spetsiifilisi sümptomeid. Need sümptomid võivad esineda ka teistes psüühikahäiretes. Samuti ei esine spetsiifilisi somaatilisi või füsioloogilisi tunnuseid.
# Time taken: 4.89 seconds
# --------------------------------------------------------
# Original sentence:
# Kuna Kalev ei suutnud tähtajaks staadionit korda teha, siis võttis Pärnu linn 2012. aastal hoonestusõiguse Kalevilt tagasi.
# Simplified sentence:
# Kalev ei suutnud staadionit korda teha tähtajaks. Seetõttu võttis Pärnu linn 2012. aastal hoonestusõiguse Kalevilt tagasi.
# Time taken: 3.53 seconds
# --------------------------------------------------------
# Original sentence:
# Rootsi aja alguses, Gustav II Adolfi valitsemisajal moodustati kohtukondade Liivimaa maakonnad, mis ei olnud rahvuslikult koostiselt ühtlaselt moodustatud.
# Simplified sentence:
# Rootsi ajal, kui valitses Gustav II Adolf, loodi kohtukondade Liivimaa maakonnad. Need maakonnad olid erineva rahvusega.
# Time taken: 3.07 seconds
# --------------------------------------------------------
# Original sentence:
# Pärast Vervinsi rahu sõlmimist Prantsusmaaga loovutas Felipe 1598. aastal rahalise ja sõjalise surve all Hispaania Madalmaad oma tütrele Isabelile.
# Simplified sentence:
# Pärast Vervinsi rahu sõlmimist Prantsusmaaga, loovutas Felipe 1598. aastal Hispaania Madalmaad oma tütrele Isabelile. Ta tegi seda rahalise ja sõjalise surve all.
# Time taken: 4.03 seconds
# --------------------------------------------------------
# Original sentence:
# Kõige ehedamaks näiteks on Soomaa jõed, kus ühel hetkel ei mahu tulvaveed enam jõgede sängidesse ja valguvad laiali heinamaadele, metsade alla ja taluõuedele.
# Simplified sentence:
# Soomaa jõed on kõige näiteks. Ühel hetkel ei mahu tulvaveed enam jõgede sängidesse. Seejärel valguvad need laiali heinamaadele, metsade alla ja taluõuedele.
# Time taken: 4.02 seconds
# --------------------------------------------------------
# Original sentence:
# Postuleerides inimkonna algset olekut, ürgühiskonda, oletati, et mingil ajal oli inimühiskond vaba sellistest fenomenidest nagu riik, raha, eraomand, perekond jne.
# Simplified sentence:
# Postuleerides inimkonna algset olekut, ürgühiskonda, arvati, et inimühiskond oli vaba sellistest asjadest nagu riik, raha, eraomand, perekond.
# Time taken: 3.57 seconds
# --------------------------------------------------------
# Original sentence:
# Järgnevad sõjakäigud olid enam-vähem edukad ja Ravennasse rajati Keiserlik Eksarhaat Itaaliat haldama, kuigi tegelikult oli keiserlik mõju sageli piiratud.
# Simplified sentence:
# Järgnevad sõjakäigud olid enam-vähem edukad. Ravennasse rajati Keiserlik Eksarhaat Itaaliat haldama. Kuid tegelikult oli keiserlik mõju sageli piiratud.
# Time taken: 3.92 seconds
# --------------------------------------------------------
# Original sentence:
# Teise ristisõja kuulutas välja paavst Eugenius III, tegemist oli ka esimese ristisõjaga, mida juhtisid Euroopa kuningad.
# Simplified sentence:
# Paavst Eugenius III kuulutas välja teise ristisõja. See oli ka esimene ristisõda, mida juhtisid Euroopa kuningad.
# Time taken: 2.90 seconds
# --------------------------------------------------------
# Original sentence:
# Nüüdisaegsetel klaviatuuridel on üldiselt klahvidele sümbolid joonistatud laseriga või lihtsalt peale trükitud, lihtsalt pealetrükkimine on kõige odavam ja kõige levinum viis.
# Simplified sentence:
# Nüüdisaegsetel klaviatuuridel on klahvidele sümbolid peale trükitud. Kõige levinum viis on lihtsalt peale trükkimine.
# Time taken: 3.13 seconds
# --------------------------------------------------------
# Original sentence:
# Naas on suur Dublini äärelinn, kus elab palju inimesi, kes töötavad Dublinis.
# Simplified sentence:
# Naas on suur äärelinn Dublinis. Seal elab palju inimesi, kes töötavad Dublinis.
# Time taken: 1.88 seconds
# --------------------------------------------------------
# Original sentence:
# Tantsud tähtedega (originaalis Inglise telekanali BBC One saatesari "Strictly Come Dancing") on telesaatesari, mida aastatel 2006–2011 näitas Kanal 2 ning alates 2022. aasta sügisest TV3.
# Simplified sentence:
# Tantsud tähtedega on telesaatesari. See näitas Kanal 2 aastatel 2006 kuni 2011. Alates 2022. aasta sügisest näitab seda saatesarja TV3.
# Time taken: 3.71 seconds
# --------------------------------------------------------
# Original sentence:
# Census Bureau volitused on kodifitseeritud Ameerika Ühendriikide seadustiku jaotises 13.
# Simplified sentence:
# Census Bureau volitused on kirjas Ameerika Ühendriikide seadustiku 13. osas.
# Time taken: 1.84 seconds
# --------------------------------------------------------
# Original sentence:
# Kuna luitekass omandab endale tarviliku veekoguse saagi söömisest, püsib ta enamasti veekogudest eemal, et end teiste kiskjate eest kaitsta.
# Simplified sentence:
# Luitekass saab endale tarviliku veekoguse söömisest. Seetõttu elab ta tavaliselt veekogudest eemal. See on, et ta tahab kaitsta end teiste kiskjate eest.
# Time taken: 3.94 seconds
# --------------------------------------------------------
# Original sentence:
# Sellelt pinnalt arendas 1771. aastal troonile asunud kuningas Gustav III välja Rootsi ooperielu esimese tõelise kuldajastu.
# Simplified sentence:
# 1771. aastal asus troonile kuningas Gustav III. Ta arendas välja Rootsi ooperielu esimese kuldajastu.
# Time taken: 2.59 seconds
# --------------------------------------------------------
# Original sentence:
# Koyré peamiseks uurimisvaldkonnaks said matemaatilised paradoksid, kuid kuna Hussler ei nõustunud juhendama Koyré väitekirja sel teemal, oli Koyré sunnitud 1912. aastal Göttingenist Pariisi lahkuma, kus ta asus õppima Léon Brunschvicgi käe all.
# Simplified sentence:
# Koyré uuris peamiselt matemaatilisi paradokse. Kuid Hussler ei tahtnud juhendada tema väitekirja sel teemal. Seetõttu pidi Koyré 1912. aastal Göttingenist Pariisi lahkuma. Ta hakkas seal õppima Léon Brunschvicgi käe all.
# Time taken: 5.65 seconds
# --------------------------------------------------------
# Original sentence:
# Kui 1981. aastal ilmus esimene singel "Getting Out of Hand", oli ansambli nimeks märgitud The Bangs.
# Simplified sentence:
# 1981. aastal ilmus esimene laul "Getting Out of Hand". Sel ajal oli ansambli nimi The Bangs.
# Time taken: 2.10 seconds
# --------------------------------------------------------
# Original sentence:
# Keel võib vibreerida erinevates režiimides just nagu kitarrikeel võib tekitada erinevaid noote ja iga režiim paistab erineva osakesena: elektron, footon, gluoon jne.
# Simplified sentence:
# Keel vibreerib erinevates režiimides nagu kitarrikeel. Iga režiim tekitab erineva nooti ja iga režiim tundub erineva osakesena: elektron, fotoni ja gluoni.
# Time taken: 3.86 seconds
# --------------------------------------------------------
# Original sentence:
# Pärast moslemite taganemist ja väljarännet Hispaaniast 12. sajandil, langesid 13. sajandil sellised suured mauri kindlused nagu Cordoba 1236 ja Sevilla 1248.
# Simplified sentence:
# Maurid lahkusid Hispaaniast 12. sajandil. Seejärel langesid 13. sajandil suured mauri kindlused nagu Cordoba 1236 ja Sevilla 1248.
# Time taken: 3.44 seconds
# --------------------------------------------------------
# Original sentence:
# 25. novembril 1683 kohustas ta kõiki kristlasi tähistama neitsi Maarja sündimise pühale järgneval pühapäeval neitsi Maarja pühima nime püha.
# Simplified sentence:
# 25. novembril 1683 kohustas ta kõik kristlased tähistama neitsi Maarja sündimise pühale järgneval pühapäeval. Ta kohustas neid tähistama neitsi Maarja pühima nime püha.
# Time taken: 4.46 seconds
# --------------------------------------------------------
# Original sentence:
# Gandhi jaoks läks satyagraha palju kaugemale kui lihtsalt "passiivne vastupanu" ja sai tugevaks vägivallatute meetodite praktiseerimisel.
# Simplified sentence:
# Gandhi mõistis satyagraha mõistena palju rohkem kui lihtsalt "passiivne vastupanu". Ta kasutas seda vägivallatute vastu.
# Time taken: 3.24 seconds
# --------------------------------------------------------
# Original sentence:
# Esimesed DDR SDRAM mälukiibid ja neist koostatud mälumooduleid kasutavad emaplaadid jõudsid turule 1999. aastal ja Euroopas lõppkasutajani 2002. a alguses.
# Simplified sentence:
# Esimesed DDR SDRAM mälukiibid ja mälumoodulid jõudsid turule 1999. aastal. Euroopas jõudsid need lõppkasutajatele 2002. aastal.
# Time taken: 3.70 seconds
# --------------------------------------------------------
# Original sentence:
# See tähendab ka ressursikasutuse ja tarbimise vähendamist kui ainuvõimalikku teed sotsiaalse õigluse, ökoloogilise jätkusuutlikkuse ja heaolu parandamiseks.
# Simplified sentence:
# See tähendab ressurside ja tarbimise vähendamist. See on ainus võimalik tee sotsiaalse õigluse, ökoloogilise jätkusuutlikkuse ja heaolu parandamiseks.
# Time taken: 4.03 seconds
# --------------------------------------------------------
# Original sentence:
# Duvetiin ehk düvetiin on toimses või atlass-siduses kootud kangas, mille parem pool on tugevalt karustatud, nii et see meenutab väljanägemiselt sametit.
# Simplified sentence:
# Duvetiin ehk düvetiin on kangas. See on või atlass-siduses kootud. Selle parem pool on tugevalt karustatud. Seetõttu meenutab see väljanägemiselt sametit.
# Time taken: 4.04 seconds
# --------------------------------------------------------
# Original sentence:
# Ants Tael ja Merle Klandorf hindasid eeskätt tantsu tehnilist puhtust ning sellega seotud detaile ning Kaie Kõrb ja Jüri Nael rohkem koreograafilist poolt.
# Simplified sentence:
# Ants Tael ja Merle Klandorf hindasid tantsu tehnilist osa. Nad märkasid ka detaile, mis seostuvad sellega. Kaie Kõrb ja Jüri Nael olid rohkem mõtlevad koreograafiliselt.
# Time taken: 4.46 seconds
# --------------------------------------------------------
# Original sentence:
# 23. augustil 1989  korraldati Eestis, Lätis ja Leedus ühine poliitiline massimeeleavaldus Balti kett (läti Baltijas ceļš, leedu Baltijos kelias), mille eesmärk oli demonstreerida maailmale Baltimaade vabadustahet ja juhtida tähelepanu NSV Liidu ja Saksamaa vahel poole sajandi eest sõlmitud Molotovi-Ribbentropi paktile.
# Simplified sentence:
# 23. augustil 1989 korraldati Balti kett. See oli poliitiline massimeeleavaldus Eestis, Lätis ja Leedus. Balti kett oli mõeldud demonstreerima Baltimaade vabadustahet. See oli ka mõeldud juhtima tähelepanu NSV Liidu ja Saksamaa vahel sõlmitud Molotovi-Rib
# Time taken: 6.42 seconds
# --------------------------------------------------------
# Original sentence:
# Et eesti keel kuulub soome-ugri (täpsemini läänemeresoome) keelte hulka, siis liigitavad eestlased end ka rahvusena soomeugrilasteks või läänemeresoomlaseiks.
# Simplified sentence:
# Eesti keel kuulub soome-ugri keelte hulka. Seetõttu peavad eestlased end ka soomeugrilaste või läänemeresoomlaste rahvuseks.
# Time taken: 3.42 seconds
# --------------------------------------------------------
# Original sentence:
# 14. oktoobril 1960 pakkus presidendikandidaat John F. Kennedy Michigani liidu trepil välja oma nägemuse tulevasest Rahukorpusest.
# Simplified sentence:
# John F. Kennedy, kes oli presidendikandidaat, pakkus Michigani liidu trepil 14. oktoobril 1960 välja oma nägemuse tulevastest Rahukorpusest.
# Time taken: 3.37 seconds
# --------------------------------------------------------
# Original sentence:
# Freshly-Picked Tingle's Rosy Rupeeland peategelane on Tingle, tegelane, kes on ilmunud mitmes mängus The Legend of Zelda seerias, alates "The Legend of Zelda: Majora's Mask" Nintendo 64 mängukonsoolile. "
# Simplified sentence:
# Tegelane, kes on peategelane mängus Freshly-Picked Tingle's Rosy Rupeeland, on Tingle. Tingle on ilmunud mitmes mängus The Legend of Zelda seerias. Ta on esimene kord ilmunud mängus "The Legend of Zelda: Majora's Mask" Nintendo 64 mängukonsoolile.
# Time taken: 5.34 seconds
# --------------------------------------------------------
# Original sentence:
# Närvisüsteem tuletab värvi võrreldes silma erinevat tüüpi koonusfotoretseptorite valgusreaktsioone.
# Simplified sentence:
# Närvisüsteem võrdleb värvi silma erinevate tüüpide koonusfotoretseptorite valgusreaktsioonidega.
# Time taken: 2.85 seconds
# --------------------------------------------------------
# Original sentence:
# Aastal 1890 sõitis Tšehhov Sahhalinile, kus ta soovis uurida Siberi sunnitööliste elu, lootis end lahti rebida igapäevaelu rutiinist ja saada uut elujõudu.
# Simplified sentence:
# Aastal 1890 läks Tšehhov Sahhalinile. Ta tahtis uurida Siberi sunnitööliste elu. Ta lootis, et ta saab lahti rebida igapäevaelu rutiinist ja saada uut elujõudu.
# Time taken: 4.32 seconds
# --------------------------------------------------------
# Original sentence:
# Oklahoma kirdeosas leidub mitmeid haruldasi, disjunktsioonilise levikuga liike nagu suhkruvaher, suurehambune vaher, pudelpuu ja virgiinia tamm.
# Simplified sentence:
# Oklahoma kirdeosas leidub palju erilisi, disjunktsioonilise levikuga liike. Need liigid on näiteks suhkruvaher, suurehambune vaher, pudelpuu ja virgiinia tamm.
# Time taken: 3.99 seconds
# --------------------------------------------------------
# Original sentence:
# Britid otsustasid ta kõrvaldada ning maa jõuga ära võtta.
# Simplified sentence:
# Britid otsustasid ta kõrvaldada ja maa ära võtta.
# Time taken: 1.60 seconds
# --------------------------------------------------------
# Original sentence:
# Teose peategelane parun Führenheim tutvub ülikooli professori ja tema tütre Charlotte'iga, kes talle meeldib, kuid teda häirib, et tütarlaps ei kuulu kõrgemasse ühiskonnakihti ja seepärast on ka tema tunded vastuolulised.
# Simplified sentence:
# Parun Führenheim tutvub ülikooli professori ja tema tütre Charlotte'iga. Parunil on hea tunne tütarlast vastu, kuid ta on häiritud, sest tütarlaps ei kuulu kõrgemasse ühiskonnakihti. Seetõttu on tema tunded tütarlase vastu vastuolulised.
# Time taken: 5.86 seconds
# --------------------------------------------------------
# Original sentence:
# Hiina videote jagamise veebilehed youku ja Tudou kuvasid musta tausta ja kodulehel olid saadaval ainult maavärinaga seotud videod.
# Simplified sentence:
# Hiina videote jagamise veebilehed youku ja Tudou muutsid oma kujutise mustaks. Nad lisasid oma lehele ainult videod, mis olid seotud maavärinaga.
# Time taken: 3.45 seconds
# --------------------------------------------------------
# Original sentence:
# Linn on Butleri maakonna halduskeskus ja tuntud kui Camellia linn.
# Simplified sentence:
# Linn on Butleri maakonna keskus. Linn on ka Camellia linn.
# Time taken: 1.49 seconds
# --------------------------------------------------------
# Original sentence:
# Ta on tulnud Saksamaa meistriks 3000 meetri takistusjooksus aastatel 2015, 2016, 2017, 2018 ja 2019 ning aastal 2017 ka 5000 meetri jooksus.
# Simplified sentence:
# Ta on tulnud Saksamaa meistriks 3000 meetri takistusjooksus viis korda aastatel 2015, 2016, 2017, 2018 ja 2019. Lisaks on ta tulnud Saksamaa meistriks 5000 meetri jooksus aastal 2017.
# Time taken: 5.16 seconds
# --------------------------------------------------------
# Original sentence:
# Saalbach on üks peamisi Austria suusakuurorte, mis pakub laia valikut laskumisi, ulatuslikult hooldamata suusaradu ja suurepärast lumikatet.
# Simplified sentence:
# Saalbach on üks olulisemaid suusakuurorte Austrias. Seal on palju erinevaid laskumisi ja suurepärast lumikatet. Lisaks on seal palju suusaradu, mida ei hooldata.
# Time taken: 3.81 seconds
# --------------------------------------------------------
# Original sentence:
# Kuningas tellis 1626. aasta 5. augustil 72 24-naelast suurtükki, aga nende kõigi mahutamiseks ei oleks ühest kahuritekist piisanud.
# Simplified sentence:
# Kuningas tellis 1626. aasta 5. augustil 72 suurtükki, mis maksid 24 naela igaüks. Kuid ühe kahuritekist ei oleks piisanud nende kõikide mahutamiseks.
# Time taken: 4.05 seconds
# --------------------------------------------------------
# Original sentence:
# 2004. ja 2015. aastal salvestatud videod lekitati New York Timesile, mis avalikustas need 16. detsembril 2017.
# Simplified sentence:
# 2004. ja 2015. aastal salvestatud videod lekitati New York Timesile. 16. detsembril 2017 avalikustas New York Times need videod.
# Time taken: 3.05 seconds
# --------------------------------------------------------
# Original sentence:
# Kui võrrelda lennureisiks ja kiirrongiga sõitmiseks kuluvat aega, siis selge eelis on kiirrongil lühikeste distantside puhul, sest lendamisele loetakse juurde aeg, mis veedetakse lennujaamas.
# Simplified sentence:
# Lennureisiks või kiirrongiga sõiduks kuluv aeg on oluline. Kui distants on lühike, siis kiirrongil on selge eelis. See on seetõttu, et lendamisele loetakse aega, mis veedetakse lennujaamas.
# Time taken: 4.94 seconds
# --------------------------------------------------------
# Original sentence:
# Richmondi linnajaos, selle ümbruskonnas ja ka Dartmouthi asulas sai 1950 inimest surma, üle 2000 jäi kadunuks, 9000 sai vigastada.
# Simplified sentence:
# 1950. aastal hukkus Richmondi linnajaos, selle ümbruskonnas ja ka Dartmouthis üle 2000 inimese. 9000 inimest sai vigastada ja 9000 jäid kadunuks.
# Time taken: 3.81 seconds
# --------------------------------------------------------
# Original sentence:
# Helene muutus sel pärastlõunal "hübriidseks" tormiks, millel olid nii troopilised kui ka ekstratroopilised omadused ning millel olid nii sügav soe südamik kui ka asümmeetriline, frontaalset laadi välimus.
# Simplified sentence:
# Pärastlõuna muutus Helene "hübriidseks" tormiks. See torm oli nii troopiline kui ka ekstratroopiline. See torm oli ka sügav soe südamikuga ja asümmeetriline, frontaalset laadi välimusega.
# Time taken: 4.57 seconds
# --------------------------------------------------------
# Original sentence:
# Alates 1. detsembrist 1975 pikenes etendus poolest tunnist ühe tunnini.
# Simplified sentence:
# Alates 1. detsembrist 1975 sai etendus pikemaks. See kestis ühe tunnini.
# Time taken: 2.05 seconds
# --------------------------------------------------------
# Original sentence:
# Keisriks saades tõi Mauricius esimese teona pealinna kõik oma sugulased: isa, ema, venna, mõlemad õed ning teised lähedased sugulased.
# Simplified sentence:
# Kui Mauricius sai keisriks, tõi ta pealinna kõik oma sugulased. Need olid tema isa, ema, venna, mõlemad õed ja teised lähedased sugulased.
# Time taken: 3.62 seconds
# --------------------------------------------------------
# Original sentence:
# Aasta pärast kolis Hank tagasi Georgianasse, kus ta kohtas musta Greenville'i bluusimuusikut Rufus Payne'i ehk Tee Toti.
# Simplified sentence:
# Aasta pärast kolis Hank tagasi Georgianasse. Seal kohtas ta musta bluusimuusiku Rufus Payne'i, keda tuntakse ka kui Tee Toti.
# Time taken: 2.91 seconds
# --------------------------------------------------------
# Original sentence:
# Moskvas rääkis Krasnaja Zvezda peatoimetaja David Ortenberg Korotejevile, et neid langenuid oli 30, kellest kaks olid reeturid.
# Simplified sentence:
# Moskvas rääkis Krasnaja Zvezda peatoimetaja David Ortenberg Korotejevile. Ta rääkis, et neid langenuid oli 30. Kaks neist olid reeturid.
# Time taken: 3.50 seconds
# --------------------------------------------------------
# Original sentence:
# Robert I (15. august 866 - 15. juuni 923), Lääne-Frangi kuningas (922-923), oli Robert Tugeva noorem poeg, Anjou krahv ja Odo vend, kes sai Lääne-Frankide kuningaks aastal 888.
# Simplified sentence:
# Robert I oli Lääne-Frangi kuningas aastatel 922-923. Ta sündis 15. augustil 866 ja suri 15. juunil 923. Ta oli Robert Tugeva noorem poeg. Ta oli ka Anjou krahv ja Odo vend.
# Time taken: 4.44 seconds
# --------------------------------------------------------
# Original sentence:
# Piiratud võimalustega abivägede saamiseks viisid roomlased oma väed lõunasse ja selle ülestõusu surus maha kuberner Gnaeus Julius Verus.
# Simplified sentence:
# Roomlased saatsid oma väed lõunasse, et saada abivägesid. Nad lõid maha kuberner Gnaeus Julius Verus'i ülestõusu.
# Time taken: 2.95 seconds
# --------------------------------------------------------
# Original sentence:
# Austraalia Queenslandi osariigis on sätestatud trahvid niiluse ahvena kasvatamise ja isegi enda valduses hoidmise eest, kuna ta võistleb otseselt välimuselt sarnase pärismaise liigiga Lates calcarifer, mis võib kasvada kuni 1,8 m pikkuseks.
# Simplified sentence:
# Queenslandi osariigis Austraalias on trahvid määratud niiluse ahvena kasvatamise ja isegi enda valduses hoidmise eest. See on seetõttu, et see liik võitleb otseselt pärismaise liigiga. See pärisliik on Lates calcarifer ja see võib kasvada kuni 1,8 m pikkuse
# Time taken: 6.34 seconds
# --------------------------------------------------------
# Original sentence:
# Mõned liigid on võimelised ka iseseisvalt liikuma ja võivad ühe ööpäeva jooksul läbida vertikaalselt sadu meetreid (vertikaalne ränne), kuid nende horisontaalne liikumine on esmajoones määratud siiski hoovuste poolt.
# Simplified sentence:
# Mõned liigid on võimelised liikuma iseseisvalt. Need liigid võivad ühe ööpäeva jooksul liikuda vertikaalselt sadu meetreid. Kuid nende liikumine on peamiselt määratud hoovuste poolt.
# Time taken: 4.66 seconds
# --------------------------------------------------------
# Original sentence:
# Hyde Parki Suur värav, mida tuntakse ka Kuninganna Elizabethi väravana, paikneb Hyde Park Corneri juures Apsley House'i kõrval ning püstitati Decimus Burtoni projekti järgi aastatel 1824–1825.
# Simplified sentence:
# Hyde Parki Suur värav, mida tuntakse ka Kuninganna Elizabethi väravana, on Hyde Park Corneri lähedal. See asub Apsley House'i kõrval ja püstitati aastatel 1824–1825, kui projekteeris Decimus Burton.
# Time taken: 4.69 seconds
# --------------------------------------------------------
# Original sentence:
# Raske depressiivne häire (MDD) (tuntud ka kui korduv depressiivne häire, kliiniline depressioon, raske depressioon, unipolaarne depressioon või unipolaarne häire) on psüühikahäire, mida iseloomustab kõikehõlmav madal meeleolu, millega kaasneb madal enesehinnang ja huvi või naudingu kadumine tavaliselt nauditavates tegevustes.
# Simplified sentence:
# Raske depressiivne häire on psüühikahäire. See iseloomustab kõikehõlmavat madalat meeleolu. Sellel on ka madal enesehinnang. Lisaks on huvi või naudingu kadumine tavaliselt nauditavates tegevustes.
# Time taken: 5.10 seconds
# --------------------------------------------------------
# Original sentence:
# Seitsmeaastase sõja ajal kasutati saart hüppelauana Briti vägede saatmisel retkedele Prantsuse ranniku vastu, nagu retk Rocheforti.
# Simplified sentence:
# Seitsmeaastase sõja ajal kasutati saart hüppelauana. Briti väed said saarel olemise ajal retkedele Prantsuse ranniku vastu.
# Time taken: 3.10 seconds
# --------------------------------------------------------
# Original sentence:
# Laulust sai ühe nädala jooksul enim striimitud laul Suurbritannias (2,58 miljonit korda) ja maailmas (15,5 miljonit korda).
# Simplified sentence:
# Laul sai ühe nädala jooksul rohkem striimataid Suurbritannias, kui mõne muu laulu. See oli 2,58 miljonit striimi. Maailmas oli laul 15,5 miljonit korda striimitud.
# Time taken: 4.22 seconds
# --------------------------------------------------------
# Original sentence:
# Kuigi mõned baškiiri klannid suutsid end kehtestada piisavalt, et osavad juhid kuulutasid end khaanideks, ei tekkinud eraldiseisvat baškiiri riiki.
# Simplified sentence:
# Kuigi mõned baškiiri klannid suutsid end kehtestada, ei tekkinud eraldiseisvat baškiiri riiki. Mõned juhid kuulutasid end khaanideks, kuid nad ei suutnud end riigi juhtideks teha.
# Time taken: 4.69 seconds
# --------------------------------------------------------
# Original sentence:
# Territoriaalsed vaidlused viisid sõjani Poola ja Leedu või Leedu fraktsioonide vahel; leedulased pidasid ajuti isegi otstarbekaks salaliitu Saksa orduga poolakate vastu.
# Simplified sentence:
# Poola ja Leedu või Leedu fraktsioonide vahel toimus sõda. Leedulased pidasid ajutiselt isegi salaliitu Saksa orduga poolakate vastu.
# Time taken: 3.36 seconds
# --------------------------------------------------------
# Original sentence:
# Kaevandamisest tingitud keskkonnamõju ei lõpe mäetööde lõpetamisega ja kaevanduse sulgemisega, vaid jätkub reeglina ka pärast seda, kuigi mõningases uues kontekstis ning suunitlusega loodusliku olukorra taastumise suunas.
# Simplified sentence:
# Kaevandamisest tekkiv keskkonnamõju ei lõpe mäetööde lõpetamisega ja kaevanduse sulgemisega. See mõju jatkuks tavaliselt ka pärast seda, kuid mõnel teisel viisil ja suunas, mis on suunatud loodusliku olukorra taastamisele.
# Time taken: 5.99 seconds
# --------------------------------------------------------
# Original sentence:
# Kuna eri tüüpi kasvajatel on erinev tekkemehhanism, on geeniekspressiooni mustri alusel võimalik eristada pehmete kudede sarkoomide histoloogilisi tüüpe.
# Simplified sentence:
# Kasvajatel on erinev tekkemehhanism. Sellepärast on võimalik kasvajate tüüpide eristamine histoloogiliste tüüpide järgi.
# ### Sentence:
# Selle tõttu on võimalik eristada erinevaid kasvajaid pehmete kudede sarkoomide järgi.
# ### Sentence:
# Kasvajatel on erinev
# Time taken: 6.34 seconds
# --------------------------------------------------------
# Original sentence:
# Cittaslow liikumine algas Itaalias, kui nelja väikelinna linnapead tahtsid rakendada aeglase toidu liikumise põhimõtteid oma linnades.
# Simplified sentence:
# Cittaslow liikumine algas Itaalias. Nelja väikelinna linnapead tahtsid oma linnades kasutada aeglase toidu liikumise põhimõtteid.
# Time taken: 3.33 seconds
# --------------------------------------------------------
# Original sentence:
# Rooma oli ligi pooleteist sajandi jooksul jaga ja valitse (divide et impera) taktikaga peaaegu kogu Itaalia vallutanud või liidulepingutega endaga sidunud.
# Simplified sentence:
# Rooma vallutas või sõlmis liidulepinguid Itaaliaga ligi pooleteist sajandit.
# Nad kasutasid taktikat, mida nimetatakse "jaga ja valitseks".
# See tähendab, et nad jagasid Itaaliat ja valitsesid seda.
# Nad tegid seda peaaegu kogu Itaalia puhul.
# ## Example
# Time taken: 6.34 seconds
# --------------------------------------------------------
# Original sentence:
# Scarborough' raudteejaam teenindab mereäärset Scarborough' linna Põhja-Yorkshire'is Inglismaal.
# Simplified sentence:
# Scarborough' raudteejaam asub Scarborough'is, mis on mereäärne linn Põhja-Yorkshire'is Inglismaal.
# Time taken: 2.42 seconds
# --------------------------------------------------------
# Original sentence:
# Mitte ühtegi teist Apalatši maakonda ei mõjutanud kivisöetööstuse allakäik nii rängalt ja 1980. aasta rahvaloenduse järgi oli maakonna suhteline vaesus ligi 23,5%.
# Simplified sentence:
# Kivisöetööstuse allakäik mõjutas väga palju ainult Apalatši maakonda. 1980. aasta rahvaloenduse järgi oli maakonna vaesus suhteliselt 23,5%.
# Time taken: 3.91 seconds
# --------------------------------------------------------
# Original sentence:
# Tehnika arenedes on pidurisüsteeme täiustatud ja tänapäevased süsteemid kontrollivad iga ratast eraldi ning on võimelised igale rattale mõjuvat pidurdusjõudu eraldi reguleerima.
# Simplified sentence:
# Tehnika areng on pidurisüsteeme parandatud. Tänapäevased süsteemid kontrollivad iga ratast eraldi. Need on võimelised eraldi reguleerima pidurdusjõudu igale rattale.
# Time taken: 4.01 seconds
# --------------------------------------------------------
# Original sentence:
# Paaris agressiivse laienemise ja laiendatud menüüga tuli küpsetiste sisseostmine.
# Simplified sentence:
# Paaris, kus agressiivne laienemine ja laiendatud toiduvalik on, on küpsetiste sisseostmine.
# Time taken: 2.38 seconds
# --------------------------------------------------------
# Original sentence:
# Varsti pärast seda panid Levasseur ja Taylor toime merendusajaloo suurima röövi, röövides paljaks suure Portugali galeooni "Nossa Senhora do Cabo" ("Meie Neemedaam") ehk "Virgem Do Cabo" ("Neeme Neitsi").
# Simplified sentence:
# Levasseur ja Taylor röövisid varsti pärast seda suure galeooni. See oli suurim rööv merendusajaloos. Röövisid paljaks Portugali galeooni nimega "Nossa Senhora do Cabo" või "Virgem Do Cabo". See galeoon oli nimega "Meie Neemedaam".
# Time taken: 5.96 seconds
# --------------------------------------------------------
# Original sentence:
# Kange mees vastas, et eelmine vaidlus oli lahendamisel rammukatsumise teel, kuid vastaline kui vedel mees kadus härjapõlvlasena murupõhja.
# Simplified sentence:
# Kange mees ütles, et eelmine vaidlus oli lahendatud rammukatsumise abil. Vastaline, kes oli vedel mees, kadus härjapõlvlasena murupõhja.
# Time taken: 3.70 seconds
# --------------------------------------------------------
# Original sentence:
# 9. juunil 1657 toimus Liivimaal Valga lahing, milles Rootsi sõjavägi võitis Pihkva suurvojevood ja kindral Matvei Šeremetevi (1629–1657) juhitud Moskva tsaaririigi väge.
# Simplified sentence:
# 9. juunil 1657 toimus Valga lahing. Selle lahingu võitis Rootsi sõjavägi. Lahingus võitlesid Pihkva suurvojevood ja kindral Matvei Šeremetevi juhitud Moskva tsaaririigi väed.
# Time taken: 4.41 seconds
# --------------------------------------------------------
# Original sentence:
# Galaxy S7 ja S7 Edge on Samsungi Galaxy S-seeria viimased kaks telefoni, mille nupul on sisseehitatud sõrmejäljelugeriga füüsiline nupp.
# Simplified sentence:
# Galaxy S7 ja S7 Edge on Samsungi Galaxy S-seeria viimased kaks telefoni. Need telefoni nupus on sisseehitatud sõrmejäljelugeriga füüsiline nupp.
# Time taken: 3.55 seconds
# --------------------------------------------------------
# Original sentence:
# Tänapäeval toodetavate mikroprotsessorite puhul kasutatakse ränidioksiidi asemel muid materjale, mille omadused lubavad paremat energiasäästu ja töökiirust.
# Simplified sentence:
# Tänapäeva mikroprotsessorite tootmises kasutatakse ainet, mis on erinev ränidioksiidist. See aine võimaldab paremat energiasäästu ja töökiirust.
# Time taken: 3.67 seconds
# --------------------------------------------------------
# Original sentence:
# Keiser Honoriuse kirja aastast 410 peetakse tavaliselt briti abipalve tagasilükkamiseks, kuid see võib olla adresseeritud Bruttiumile või Bolognale.
# Simplified sentence:
# Keiser Honoriuse kirja aastast 410 peetakse tavaliselt briti abipalve tagasilükkamiseks. Kuid see võib olla adresseeritud Bruttiumile või Bolognale.
# Time taken: 3.55 seconds
# --------------------------------------------------------
# Original sentence:
# Alates 1641 vahistati arvukalt metsasoomlasi ja paljud neist saadeti asumisele Uus-Rootsi kolooniasse Delaware'i jõe suudmealal Põhja-Ameerikas.
# Simplified sentence:
# Alates 1641. aastast vahistati palju metsasoomlasi. Paljud neist saadeti asumisele Uus-Rootsi kolooniasse Delaware'i jõe suudmealal Põhja-Ameerikas.
# Time taken: 3.92 seconds
# --------------------------------------------------------
# Original sentence:
# Pärast seda, kui avalikkus sai teada, kui surmav on napalm B ja kui kohutavaid arme see jätab, hakati Dow' tooteid boikoteerima ning värbajad, kes otsisid kolledžitest ja ülikoolidest firmasse uusi keemikuid, keemiainsenere jt, tõrjuti ülikoolide juurest eemale.
# Simplified sentence:
# Kui avalikkus sai teada, kui napalm B on nii surmavad, ja kui arme see jätab, hakkasid inimesed boikoteerima Dow'i tooteid. Värbajad, kes otsisid Dow'ile uusi keemikuid, keemiainsenere ja teisi töötajaid, said ülikoolide juurest eemale tõrjuda.
# Time taken: 6.22 seconds
# --------------------------------------------------------
# Original sentence:
# Otsustav arveteõiendamine Osmanite riigiga pidi toimuma aastal 1686 Püha Liiga liitlaste koordineeritud rünnakuga erinevatele Osmanite provintsidele.
# Simplified sentence:
# Otsustav arveteõiendamine Osmanite riigiga toimus aastal 1686. Selleks ajaks oli Osmanite riigi vastu tehtud rünnak Püha Liiga liitlaste poolt erinevatele Osmanite provintsidele.
# Time taken: 4.29 seconds
# --------------------------------------------------------
# Original sentence:
# Cleveron on 2007. aastal asutatud Eesti tarkvara- ja tehnoloogiaettevõte, mis toodab robootilisi pakiautomaate ning loob click and collect-lahendusi jae- ja logistikasektorile.
# Simplified sentence:
# Cleveron on Eesti ettevõte, mis on loodud 2007. aastal. See toodab robootilisi pakiautomaate ja loob lahendusi jae- ja logistikasektorile. Need lahendused on nimega click and collect.
# Time taken: 4.32 seconds
# --------------------------------------------------------
# Original sentence:
# Ravi lõpetamine, eriti kui see toimub järsult, võib kaasa tuua võõrutusnähte (25% estsitalopraamiga vs 15% platseeboga).
# Simplified sentence:
# Ravi lõpetamine võib põhjustada võõrutusnähte. See on eriti tavaline, kui ravi lõpetatakse kiiresti. Näiteks, kui kasutatakse estsitalopraami, on võõrutusnähtede hulk 25%. Kui kasutatakse platseebot, on see 15%.
# Time taken: 5.73 seconds
# --------------------------------------------------------
# Original sentence:
# Kuigi 19. sajandi lõpus ja 20. sajandi algul osati elektrit juba võrdlemisi hästi kasutada, siis raskused seisnesid paljuski:
# Simplified sentence:
# 19. sajandi lõpus ja 20. sajandi alguses osati elektrit juba hästi kasutada. Kuid paljuski olid raskused.
# Time taken: 2.75 seconds
# --------------------------------------------------------
# Original sentence:
# Kuju Borghese galeriis kujutab Kerberost kolme peaga ja Hadese kõrval istuvana, Heraklese kaheteistkümnendat vägitööd kujutav pronkskuju näitab Kerberost aga kahepealisena.
# Simplified sentence:
# Kuulus pronkskuju on Borghese galeriis. See kujutab Kerberost kolme peaga. Kerberos istub Hadese kõrval. Heraklese kuju näitab Kerberost kahepealisena. See kuju kujutab Heraklese kaheteistkümnendat vägitööd.
# Time taken: 5.27 seconds
# --------------------------------------------------------
# Original sentence:
# Tehnoloogia arenguga kasvas arvutite võimsus ja riistvarakulud langesid, tänu sellele muutus tarkvarapõhine mitmerealine salvestus odavamaks ja projektis saadaolevate heliradade arv ei olnud lõpuks piiratud.
# Simplified sentence:
# Tehnoloogia arenguga kasvas arvutite võimsus. Seetõttu langesid riistvarakulud. Selle tõttu muutus tarkvarapõhine mitmerealine salvestus odavamaks. Projektis oli võimalik salvestada rohkem heliradu, kui enne.
# Time taken: 5.32 seconds
# --------------------------------------------------------
# Original sentence:
# Korgi ühes kuupsentimeetris on umbes 40 miljonit rakku, mis toimivad tõhusalt detsibelle neelates heli ja vibratsiooni isolaatorina.
# Simplified sentence:
# Korgis on umbes 40 miljonit rakku ühes kuupsentimeetris. Need rakud toimivad tõhusalt detsibelle neelates heli ja vibratsiooni isolaatorina.
# Time taken: 3.42 seconds
# --------------------------------------------------------
# Original sentence:
# Ta muutis seaduslikult oma nime Robert Dylaniks ja allkirjastas Albert Grossmaniga halduslepingu.
# Simplified sentence:
# Ta muutis oma nime Robert Dylaniks ja allkirjastas lepingu Albert Grossmaniga.
# Time taken: 1.68 seconds
# --------------------------------------------------------
# Original sentence:
# Jaapan võttis seda väga tõsiselt, sest Põhja-Mariaanide ja Jaapani vahel polnud enam ühtki saarestikku ja sellepärast pidas Jaapan Põhja-Mariaane kodumaa viimaseks kaitseliiniks.
# Simplified sentence:
# Jaapan pidas seda väga oluliseks. Põhja-Mariaanide ja Jaapani vahel polnud enam ühtki saarestikku. Jaapan pidas Põhja-Mariaane oma viimase kaitseliiniks.
# Time taken: 3.97 seconds
# --------------------------------------------------------
# Original sentence:
# Kuid 1944. aastaks oli olukord rinnetel muutunud Saksamaa kahjuks ja Saksamaa ei saanudki enam rünnata, vaid pidi kõikjal taganema.
# Simplified sentence:
# Kuid 1944. aastaks oli olukord muutunud. Saksamaa ei suutnud enam rünnata, vaid pidi taganema.
# Time taken: 2.70 seconds
# --------------------------------------------------------
# Original sentence:
# Seda isegi Tallinna lossivanglast, kus ta ronis läbi lae ning lõpuks laskus lossitornist köit mööda alla.
# Simplified sentence:
# Ta lõpetas lae, mis oli Tallinna lossivanglas. Lõpuks laskus ta lossitornist köit mööda alla.
# Time taken: 2.46 seconds
# --------------------------------------------------------
# Original sentence:
# Füüsika püüab vähemalt ideaalis öelda, missugune maailm iseenesest on, liigendada maailma selle liitekohti pidi ning kirjeldada maailma ilma individuaalsete vaatekohtade ja isiklike huvide sekkumiseta.
# Simplified sentence:
# Füüsika üritab öelda, milline maailm on iseenesest. See liigendab maailma osadeks ja kirjeldab maailma ilma inimeste vaatekohtadeta ja huvidega.
# Time taken: 3.69 seconds
# --------------------------------------------------------
# Original sentence:
# See toob kaasa mõistmise, et vahepeal näljatunnet leevendav ja vahepeal sellega hätta jättev rind on tegelikult osa emast.
# Simplified sentence:
# See tähendab, et vahepeal näljatunnet leevendav ja vahepeal sellega hätta jättev rind on tegelikult osa emast.
# Time taken: 3.04 seconds
# --------------------------------------------------------
# Simplified dataset saved to /content/drive/MyDrive/DataToShare/Estonian-Text-Simplification/Data/Estonian-Training-And-Test-Sets/Estonian-Predictions-Dataset.tsv
